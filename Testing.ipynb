# %%
from SMAclass import SMABacktester

# %%
tester= SMABacktester("AAPL",50,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (16.973033, -169.365878)

# %%
tester.plot_results()

# %%
tester= SMABacktester("MSFT",50,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (0.417174, -5.450733)

# %%
tester.plot_results()

# %%
tester= SMABacktester("META",50,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.644095, -5.5375)

# %%
tester.plot_results()

# %%
tester= SMABacktester("GOOGL",50,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.574691, -7.974253)

# %%
tester.plot_results()

# %%
tester= SMABacktester("AMZN",50,200, "2000-01-01","2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (10.898681, -54.080307)

# %%
tester.plot_results()
